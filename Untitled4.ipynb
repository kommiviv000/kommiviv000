# %% [markdown]
# <a href="https://colab.research.google.com/github/kommiviv000/kommiviv000/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
###Function for reading the file##
def read_gas_prices(file_name = 'gasprices.txt'):
  # open and read the file
openfile = open("gasprices.txt",'r')
# split the line
mini_list = openfile.read().split(':')
price = float(mini_list[1])
date = mini_list[0].split(‘-’)
# do any necessary data conversions
month = mini_list[0]
month = int(month)
day = mini_list[1]
day = int(day)
year = mini_list[2]
year = int(year)
# build the mini list called price_mini_list

# append this price_mini_list to the master list prices_master_list
for index in range(5):
  price_mini_list = mini_list[index]
  print(price_mini_list)
openfile.close()
# return (None) out of the function
pass

#Function for retrieving average prices per year
def get_average_price_per_year():

 def list_sep(line):
  linedata = line.split(":")
  price = float(linedata[1])
  date = linedata[0].split('-')
  year = int(date[2])
  return year, price

 def Avgprice(year, file_list):
  sum = 0
  count = 0
  for line in file_list:
    line = line.rstrip()
    y, p = list_sep(line)
    if y == year:
      sum = sum + p
      count = count + 1
      return sum/count

#starting year 1993
#ending year 2013
gasfile = open("gasprices.txt" , 'r')
file_list = gasfile.readlines()

print(file_list)
gasfile.close()
print("Year" , " Average Price")
for year in range(1993, 2013 +1):
  print (year,": ", Avgprice(year, file_list))

print(get_average_price_per_year())

#Code for Acsending+Descending gas prices#

def high_to_low&low_to_high():
  with open("C:\BPA Python Programming\Vivek Project\gasprices.txt") as f:
      price_list = f.readlines()

  price_list = [x.strip() for x in price_list]

    just_prices = []
    just_years = []
  for i in price_list:
      year = i.split(":")[0]
      price  = i.split(":")[1]
      just_years.append(year)
      just_prices.append(price)


  tuples = zip(just_prices, just_years)

  sorted_tuples = sorted(tuples)


  reverse_sorted_list = []
  
  for tuple in sorted_tuples:
      joined_tuple = ':'.join(str(j) for j in tuple)
      .append(joined_tuple)

  sorted_list = []
  for i in reverse_sorted_list:
      x = i.split(":")
      x.reverse()
      y = ":".join(str(j) for j in x)
      sorted_list.append(y)

  print(sorted_list)
  sorted_list.reverse()
  print(sorted_list)

print(high_to_low&low_to_high())
